# %% [markdown]
# # Data Science Capstone Project
# ### Jimmy J.

# %% [markdown]
# ## Introduction
#
# ##### Frank Lloyd Wright said it best - “Tip the world over on its side and everything loose will land in Los Angeles." For decades people from all over the world have come to this city in search of home, family, love, fame, and fortune. Los Angeles welcomes this multicultural migration with a suburban sprawl that encompases over 88 cities, and even more unincorporated neihborhoods. Each of these neighborhoods are characterized by geographical, economic, and cultural features that make them uniquely poised to cater to different demographics.
#
# ##### Neighborhoods like Downtown Los Angeles, Culver City, Long Beach, Century City, and West Hollywood provide a mixture of urban style living and accessibility to grocery stores, malls, means of public transportation and entertainment venues within walking distance. On the otherhand suburbs like Baldwin Hills, Crenshaw, Echo Park and Boyle Heights are quiter neighborhoods with single family dwellings that are not easily accessible via public modes of transportation.
#
# ##### Given the vast spectrum of possibilites of neighborhoods to choose from in LA, someone looking to move here might be overwhelmed. In this project I've attempted to characterize neighborhoods in LA by the nature of venue that are in their immediate vicinities using a clustering algorithm. Results from this analysis show that neighborhoods in LA fall under a few groups, defined by the nature of the venues closest to them. This is of most interest to rental unit searching apps like Westiside Rentals or Rentpad, to real estate agents, and generally, to people looking to move to LA. The results of this project can help them find neighborhoods that are most aligned with what they are looking for in a place to live and overall, provide a more satisfactory experience than chosing a neighborhood at random.

# %% [markdown]
# ## Data
#
# ##### The list of neighborhoods in Los Angeles was web scraped from Wikipedia using BeautifulSoup. The names of these neigborhoods were then fed into Nominatim to obtain theie geographical coordinates.
#
# ##### The venues in the vicinity of these neighborhoods will be retreived using the FourSquare API search engine. Venues of five different categories were chosen: Travel & Transport, Arts & Entertainment, Outdoors & Recreation, Nightlife Spot, and Food. The number of venues of each category for each neighborhood was counted and then normalized to give five parameters with which to cluster the neighborhoods by.

# %% [markdown]
# ## Methodology

# %%
### Importing libraries 

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import re

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import bs4 as bs

import urllib.request

import requests

# %%
# @hidden_cell

CLIENT_ID = 'JS0P2BHNS4GICN4OT1LRM03JV0OLTO4QWS0I5AEITRLVI3QU' # your Foursquare ID
CLIENT_SECRET = 'KGFP21SEFHLUXM2EPAI4HDLQOAI21MC1CY24RJ4AII4UX2Q3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails: hidden')
# Out:
# Your credentails: hidden

# %%
# Scraping list of neighborhoods in LA

source = urllib.request.urlopen('http://maps.latimes.com/neighborhoods/neighborhood/list/').read()
soup=bs.BeautifulSoup(source, 'lxml')

table = soup.find('table')

table_rows = table.find_all('tr')

ls = []
for tr in table_rows:
    td = tr.find_all('a')
    row = [tr.text.strip() for tr in td]
    ls.append(row)
    
LA_neighs = pd.DataFrame(ls, columns = ['Neighborhood','Region'])

LA_neighs=LA_neighs.drop(LA_neighs.index[0])

LA_neighs.tail()
# Out:
#        Neighborhood               Region
# 268     Willowbrook           South L.A.
# 269      Wilmington               Harbor
# 270  Windsor Square         Central L.A.
# 271        Winnetka  San Fernando Valley
# 272  Woodland Hills  San Fernando Valley

# %%
# Getting the latitude and longitude of neighborhoods in LA

latitude = []
longitude = []

for name in LA_neighs['Neighborhood']:
    try:
        address = str(name)+", Los Angeles, California"
        geolocator = Nominatim(user_agent="LA_explorer")
        location = geolocator.geocode(address)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except:
        latitude.append(None)
        longitude.append(None)

LA_neighs['Latitude'] = latitude
LA_neighs['Longitude'] = longitude

# %%
LA_neighs[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-294b378cf90c> in <module>
# ----> 1 LA_neighs[:50]
#
# NameError: name 'LA_neighs' is not defined

# %%
LA_neighs.dropna(inplace = True)

# %%
LA_neighs[:50]
# Out:
#               Neighborhood                  Region   Latitude   Longitude
# 1                    Acton         Antelope Valley  34.480742 -118.186838
# 2          Adams-Normandie              South L.A.  34.018609 -118.287348
# 3             Agoura Hills  Santa Monica Mountains  34.147910 -118.765704
# 4               Agua Dulce        Northwest County  34.496382 -118.325635
# 5                 Alhambra      San Gabriel Valley  34.093042 -118.127060
# 6             Alondra Park               South Bay  33.890134 -118.335133
# 7                 Altadena                Verdugos  34.186316 -118.135233
# 8            Angeles Crest          Angeles Forest  34.234000 -118.183386
# 9                  Arcadia      San Gabriel Valley  34.136207 -118.040150
# 10                  Arleta     San Fernando Valley  34.241327 -118.432205
# 11       Arlington Heights            Central L.A.  34.128557 -118.152999
# 12                 Artesia               Southeast  33.869020 -118.079620
# 13                  Athens              South L.A.  33.920407 -118.279049
# 14         Atwater Village          Northeast L.A.  34.116398 -118.256464
# 15                  Avalon                  Harbor  33.342210 -118.327261
# 16         Avocado Heights      San Gabriel Valley  34.026983 -117.965433
# 17                   Azusa      San Gabriel Valley  34.133875 -117.905605
# 18  Baldwin Hills/Crenshaw              South L.A.  34.011551 -118.337374
# 19            Baldwin Park      San Gabriel Valley  34.085474 -117.961176
# 20                 Bel-Air                Westside  34.082728 -118.447980
# 21                    Bell               Southeast  33.974781 -118.186636
# 22              Bellflower               Southeast  33.882570 -118.116768
# 23            Bell Gardens               Southeast  33.969456 -118.150395
# 25           Beverly Grove            Central L.A.  34.059208 -118.411497
# 26           Beverly Hills                Westside  34.069650 -118.396306
# 27             Beverlywood                Westside  34.046633 -118.395038
# 28           Boyle Heights                Eastside  34.033166 -118.204865
# 29                Bradbury      San Gabriel Valley  34.146951 -117.970898
# 30               Brentwood                Westside  34.052140 -118.474070
# 32                 Burbank     San Fernando Valley  34.181648 -118.325855
# 33               Calabasas  Santa Monica Mountains  34.144664 -118.644097
# 34             Canoga Park     San Fernando Valley  34.201078 -118.597826
# 35                  Carson                  Harbor  33.832204 -118.251755
# 36                 Carthay            Central L.A.  34.056121 -118.373411
# 37                 Castaic        Northwest County  34.488882 -118.622866
# 39         Central-Alameda              South L.A.  34.163728 -118.314057
# 40            Century City                Westside  34.057426 -118.414727
# 41                Cerritos               Southeast  33.864429 -118.053932
# 42             Charter Oak      San Gabriel Valley  34.099799 -117.872593
# 43              Chatsworth     San Fernando Valley  34.259571 -118.602325
# 44    Chatsworth Reservoir     San Fernando Valley  34.259571 -118.602325
# 46           Cheviot Hills                Westside  34.045554 -118.409494
# 47               Chinatown            Central L.A.  34.063459 -118.236050
# 48                  Citrus      San Gabriel Valley  34.116070 -117.894807
# 49               Claremont           Pomona Valley  34.096676 -117.719779
# 50                Commerce               Southeast  34.002581 -118.156586
# 51                 Compton               Southeast  33.894927 -118.226624
# 52                  Covina      San Gabriel Valley  34.102400 -117.854865
# 53                  Cudahy               Southeast  33.962058 -118.183539
# 54             Culver City                Westside  34.021122 -118.396467

# %%
### Saving data to csv to acoid repeated API calls
LA_neighs.to_csv('LA_neighborhoods_v0.3.csv')

# %%
LA_Neighs=pd.read_csv('LA_neighborhoods_v0.3.csv')
LA_Neighs=LA_Neighs.drop(columns = ['Unnamed: 0'])
LA_Neighs[:50]
# Out:
#               Neighborhood                  Region   Latitude   Longitude
# 0                    Acton         Antelope Valley  34.480742 -118.186838
# 1          Adams-Normandie              South L.A.  34.018609 -118.287348
# 2             Agoura Hills  Santa Monica Mountains  34.147910 -118.765704
# 3               Agua Dulce        Northwest County  34.496382 -118.325635
# 4                 Alhambra      San Gabriel Valley  34.093042 -118.127060
# 5             Alondra Park               South Bay  33.890134 -118.335133
# 6                 Altadena                Verdugos  34.186316 -118.135233
# 7            Angeles Crest          Angeles Forest  34.234000 -118.183386
# 8                  Arcadia      San Gabriel Valley  34.136208 -118.040150
# 9                   Arleta     San Fernando Valley  34.241327 -118.432205
# 10       Arlington Heights            Central L.A.  34.128557 -118.152999
# 11                 Artesia               Southeast  33.869020 -118.079620
# 12                  Athens              South L.A.  33.920407 -118.279049
# 13         Atwater Village          Northeast L.A.  34.116398 -118.256464
# 14                  Avalon                  Harbor  33.342210 -118.327261
# 15         Avocado Heights      San Gabriel Valley  34.026983 -117.965433
# 16                   Azusa      San Gabriel Valley  34.133875 -117.905605
# 17  Baldwin Hills/Crenshaw              South L.A.  34.011551 -118.337374
# 18            Baldwin Park      San Gabriel Valley  34.085474 -117.961176
# 19                 Bel-Air                Westside  34.082728 -118.447980
# 20                    Bell               Southeast  33.974781 -118.186636
# 21              Bellflower               Southeast  33.882570 -118.116768
# 22            Bell Gardens               Southeast  33.969456 -118.150395
# 23           Beverly Grove            Central L.A.  34.059208 -118.411497
# 24           Beverly Hills                Westside  34.069650 -118.396306
# 25             Beverlywood                Westside  34.046633 -118.395038
# 26           Boyle Heights                Eastside  34.033166 -118.204865
# 27                Bradbury      San Gabriel Valley  34.146951 -117.970898
# 28               Brentwood                Westside  34.052140 -118.474070
# 29                 Burbank     San Fernando Valley  34.181648 -118.325855
# 30               Calabasas  Santa Monica Mountains  34.144664 -118.644097
# 31             Canoga Park     San Fernando Valley  34.201078 -118.597826
# 32                  Carson                  Harbor  33.832204 -118.251755
# 33                 Carthay            Central L.A.  34.056121 -118.373411
# 34                 Castaic        Northwest County  34.488882 -118.622866
# 35         Central-Alameda              South L.A.  34.163728 -118.314057
# 36            Century City                Westside  34.057426 -118.414727
# 37                Cerritos               Southeast  33.864429 -118.053932
# 38             Charter Oak      San Gabriel Valley  34.099799 -117.872593
# 39              Chatsworth     San Fernando Valley  34.259571 -118.602325
# 40    Chatsworth Reservoir     San Fernando Valley  34.259571 -118.602325
# 41           Cheviot Hills                Westside  34.045554 -118.409494
# 42               Chinatown            Central L.A.  34.063459 -118.236050
# 43                  Citrus      San Gabriel Valley  34.116070 -117.894807
# 44               Claremont           Pomona Valley  34.096676 -117.719778
# 45                Commerce               Southeast  34.002581 -118.156586
# 46                 Compton               Southeast  33.894927 -118.226624
# 47                  Covina      San Gabriel Valley  34.102400 -117.854865
# 48                  Cudahy               Southeast  33.962058 -118.183539
# 49             Culver City                Westside  34.021122 -118.396467

# %%
# Retreiving the coordinates for Los Angeles 

address = 'Los Angeles, CA'

geolocator = Nominatim(user_agent="LA_explorer")
location = geolocator.geocode(address)
LAlatitude = location.latitude
LAlongitude = location.longitude
print('The geograpical coordinate of Los Angeles are {}, {}.'.format(LAlatitude, LAlongitude))
# Out:
# The geograpical coordinate of Los Angeles are 34.0536909, -118.2427666.

# %%
# create map of LA using latitude and longitude values
map_LA = folium.Map(location=[LAlatitude, LAlongitude], zoom_start=11, width=800, height=600)

counter1=0

# add markers to map
for lat, lng, borough, neighborhood in zip(LA_neighs['Latitude'], LA_neighs['Longitude'], LA_neighs['Neighborhood'], LA_neighs['Region']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_LA)  
    counter1+=1
map_LA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Categories and IDs from FourSquare API

catIds={}
catIds={'Travel & Transport': '4d4b7105d754a06379d81259', 
        'Arts & Entertainment': '4d4b7104d754a06370d81259',
        'Outdoors & Recreation':'4d4b7105d754a06377d81259',
        'Nightlife Spot':'4d4b7105d754a06376d81259',
        'Food':'4d4b7105d754a06374d81259',
 
       }
catIds
# Out:
# {'Travel & Transport': '4d4b7105d754a06379d81259',
#  'Arts & Entertainment': '4d4b7104d754a06370d81259',
#  'Outdoors & Recreation': '4d4b7105d754a06377d81259',
#  'Nightlife Spot': '4d4b7105d754a06376d81259',
#  'Food': '4d4b7105d754a06374d81259'}

# %%
# More categories 
"""

'Travel & Transport': '4d4b7105d754a06379d81259', 
        'Arts & Entertainment': '4d4b7104d754a06370d81259',
        'Outdoors & Recreation':'4d4b7105d754a06377d81259',
        'Nightlife Spot':'4d4b7105d754a06376d81259',
        'Food':'4d4b7105d754a06374d81259'
                    'Event':'4d4b7105d754a06373d81259',
        'Professional & Other Places':'4d4b7105d754a06375d81259',
        'Residence':'4e67e38e036454776db1fb3a',
            

        'Shop & Service':'4d4b7105d754a06378d81259',
        'College & University':'4d4b7105d754a06372d81259'
        
"""

# %%
for key in catIds:
    print(key)
    print(catIds[key])
# Out:
# Travel & Transport
# 4d4b7105d754a06379d81259
# Arts & Entertainment
# 4d4b7104d754a06370d81259
# Outdoors & Recreation
# 4d4b7105d754a06377d81259
# Nightlife Spot
# 4d4b7105d754a06376d81259
# Food
# 4d4b7105d754a06374d81259

# %%
# Function to extract nearby venues 

def getNearbyVenues(names, latitudes, longitudes, categoryIds, radius, limit):
    venues_dict={}
    
    LIMIT = limit # limit of number of venues returned by Foursquare API
    radius = radius # define radius
    for key in categoryIds:
        venues_list=[]
        for name, lat, lng in zip(names, latitudes, longitudes):
            
            categoryId = categoryIds[key]
            
            url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            categoryId,
            LIMIT)
            
            # make the GET request
            
            results = requests.get(url).json()["response"]['groups'][0]['items']
        
        
            # return only relevant information for each nearby venue
            venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
            
        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
        
        venues_dict[key] = nearby_venues
    
    return(venues_dict)

# %%
venues_dict = getNearbyVenues(LA_neighs['Neighborhood'], LA_neighs['Latitude'], LA_neighs['Longitude'], categoryIds = catIds, radius = 500, limit = 100)

# %%
for key in venues_dict:
    print(key)
# Out:
# Travel & Transport
# Arts & Entertainment
# Outdoors & Recreation
# Nightlife Spot
# Food

# %%
venues_dict['Travel & Transport']
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Adams-Normandie              34.018609             -118.287348
# 1    Adams-Normandie              34.018609             -118.287348
# 2    Adams-Normandie              34.018609             -118.287348
# 3           Alhambra              34.093042             -118.127060
# 4           Alhambra              34.093042             -118.127060
# ..               ...                    ...                     ...
# 591   Woodland Hills              34.168436             -118.605838
# 592   Woodland Hills              34.168436             -118.605838
# 593   Woodland Hills              34.168436             -118.605838
# 594   Woodland Hills              34.168436             -118.605838
# 595   Woodland Hills              34.168436             -118.605838
#
#                                               Venue  Venue Latitude  \
# 0            Metro Rail - Expo Park/USC Station (E)       34.018237
# 1    Natural History Museum (NHM) Metro Bus 102/550       34.018072
# 2             Metro Rail - Expo/Vermont Station (E)       34.018241
# 3                                   Avis Car Rental       34.091506
# 4                              Days Inn Alhambra CA       34.095091
# ..                                              ...             ...
# 591                          Topanga/Woodland Hills       34.169685
# 592    Topanga Canyon Boulevard & Ventura Boulevard       34.168519
# 593                              Bus Stop Metro 150       34.168772
# 594                                Glendevon Motors       34.167908
# 595                      Knights Inn Woodland Hills       34.168148
#
#      Venue Longitude       Venue Category
# 0        -118.286094   Light Rail Station
# 1        -118.288654             Bus Stop
# 2        -118.291541   Light Rail Station
# 3        -118.124138  Rental Car Location
# 4        -118.128615                Hotel
# ..               ...                  ...
# 591      -118.605958         Intersection
# 592      -118.605850         Intersection
# 593      -118.605629             Bus Stop
# 594      -118.606049  Rental Car Location
# 595      -118.601053                Hotel
#
# [596 rows x 7 columns]

# %%
## Saving the nearby venues data as a csv to avoid repeated API calls 

for key in venues_dict:
    key1=re.sub('[^A-Za-z0-9&]+ ', '', key)
    key1=re.sub('\W+','', key1)
    venues_dict[key].to_csv(str(key1)+".csv")

# %%
LA_VENUES={}
for key in catIds:
    key1=re.sub('[^A-Za-z0-9&]+ ', '', key)
    key1=re.sub('\W+','', key1)
    LA_VENUES[key]=pd.read_csv(str(key1)+'.csv')

# %%
for key in LA_VENUES:
    print(key)
    print(LA_VENUES[key].shape)
# Out:
# Travel & Transport
# (596, 8)
# Arts & Entertainment
# (733, 8)
# Outdoors & Recreation
# (1228, 8)
# Nightlife Spot
# (640, 8)
# Food
# (3181, 8)

# %%
LA_VENUES['Food']
# Out:
#       Unnamed: 0     Neighborhood  Neighborhood Latitude  \
# 0              0  Adams-Normandie              34.018609
# 1              1  Adams-Normandie              34.018609
# 2              2  Adams-Normandie              34.018609
# 3              3  Adams-Normandie              34.018609
# 4              4  Adams-Normandie              34.018609
# ...          ...              ...                    ...
# 3176        3176   Woodland Hills              34.168436
# 3177        3177   Woodland Hills              34.168436
# 3178        3178   Woodland Hills              34.168436
# 3179        3179   Woodland Hills              34.168436
# 3180        3180   Woodland Hills              34.168436
#
#       Neighborhood Longitude                      Venue  Venue Latitude  \
# 0                -118.287348     The Habit Burger Grill       34.020192
# 1                -118.287348          Seeds Marketplace       34.020547
# 2                -118.287348                Moreton Fig       34.019775
# 3                -118.287348                Chick-fil-A       34.016633
# 4                -118.287348     Chipotle Mexican Grill       34.016956
# ...                      ...                        ...             ...
# 3176             -118.605838   El Fuego Mexican Kitchen       34.168892
# 3177             -118.605838  Darna Meditaranean Cusine       34.171741
# 3178             -118.605838              Villa Piacere       34.168338
# 3179             -118.605838                Savory Cafe       34.172049
# 3180             -118.605838                    Trimana       34.171741
#
#       Venue Longitude            Venue Category
# 0         -118.286326              Burger Joint
# 1         -118.285982                Food Court
# 2         -118.285827       American Restaurant
# 3         -118.282575      Fast Food Restaurant
# 4         -118.282584        Mexican Restaurant
# ...               ...                       ...
# 3176      -118.602021        Mexican Restaurant
# 3177      -118.605770  Mediterranean Restaurant
# 3178      -118.610297        Italian Restaurant
# 3179      -118.603941                      Food
# 3180      -118.602558                      Café
#
# [3181 rows x 8 columns]

# %%
## Aggregate number of venues of each category for each neighborhood 

LA_grouped={}
for key in LA_VENUES:
    
    LA_grouped[key]= LA_VENUES[key].groupby('Neighborhood').count()[['Venue']]
    LA_grouped[key]=LA_grouped[key].rename(columns={'Venue':str(key)})
    
    
    
    print(LA_grouped[key])
    print(LA_grouped[key].shape)
# Out:
#                    Travel & Transport
# Neighborhood
# Adams-Normandie                     3
# Alhambra                            4
# Altadena                            2
# Arcadia                             1
# Arlington Heights                   2
# ...                               ...
# Willowbrook                         1
# Wilmington                          3
# Windsor Square                      3
# Winnetka                            2
# Woodland Hills                      6
#
# [149 rows x 1 columns]
# (149, 1)
#                   Arts & Entertainment
# Neighborhood
# Adams-Normandie                     42
# Agoura Hills                         1
# Alhambra                             9
# Alondra Park                         1
# Altadena                             3
# ...                                ...
# Whittier                             6
# Whittier Narrows                     1
# Wilmington                           4
# Windsor Square                       4
# Woodland Hills                       2
#
# [168 rows x 1 columns]
# (168, 1)
#                   Outdoors & Recreation
# Neighborhood
# Adams-Normandie                      16
# Agoura Hills                          8
# Alhambra                              5
# Alondra Park                          4
# Altadena                              6
# ...                                 ...
# Whittier Narrows                      1
# Wilmington                            3
# Windsor Square                        4
# Winnetka                              3
# Woodland Hills                       14
#
# [218 rows x 1 columns]
# (218, 1)
#                  Nightlife Spot
# Neighborhood
# Adams-Normandie               4
# Alhambra                     10
# Altadena                      7
# Arcadia                       3
# Arleta                        1
# ...                         ...
# Westwood                      3
# Wilmington                    4
# Windsor Square                1
# Winnetka                      4
# Woodland Hills                7
#
# [157 rows x 1 columns]
# (157, 1)
#                  Food
# Neighborhood
# Adams-Normandie    37
# Agoura Hills        6
# Agua Dulce          5
# Alhambra           37
# Altadena            9
# ...               ...
# Willowbrook         2
# Wilmington         13
# Windsor Square     20
# Winnetka           15
# Woodland Hills     30
#
# [217 rows x 1 columns]
# (217, 1)

# %%
LA_grouped['Food']
# Out:
#                  Food
# Neighborhood
# Adams-Normandie    37
# Agoura Hills        6
# Agua Dulce          5
# Alhambra           37
# Altadena            9
# ...               ...
# Willowbrook         2
# Wilmington         13
# Windsor Square     20
# Winnetka           15
# Woodland Hills     30
#
# [217 rows x 1 columns]

# %%
LA_Neighs=LA_Neighs.set_index('Neighborhood')
print(LA_Neighs.shape)
LA_Neighs.head()
# Out:
# (251, 4)
#                  Unnamed: 0                  Region   Latitude   Longitude
# Neighborhood
# Acton                     1         Antelope Valley  34.480742 -118.186838
# Adams-Normandie           2              South L.A.  34.018609 -118.287348
# Agoura Hills              3  Santa Monica Mountains  34.147910 -118.765704
# Agua Dulce                4        Northwest County  34.496382 -118.325635
# Alhambra                  5      San Gabriel Valley  34.093042 -118.127060

# %%
# Joining to create a single dataframe of neighborhoods and number of nearby venues of each category

LA_params=LA_Neighs
for key in LA_grouped:
    print(key)
    LA_params = LA_params.join(LA_grouped[key])
    print(LA_params.shape)
LA_params=LA_params.fillna(0)
# Out:
# Travel & Transport
# (251, 5)
# Arts & Entertainment
# (251, 6)
# Outdoors & Recreation
# (251, 7)
# Nightlife Spot
# (251, 8)
# Food
# (251, 9)

# %%
#LA_params=LA_params.drop(columns = ['Unnamed: 0'])
LA_params[:50]
LA_Params=LA_params.drop(columns = ['Region', 'Latitude', 'Longitude'])
LA_Params[:50]
# Out:
#                         Travel & Transport  Arts & Entertainment  \
# Neighborhood
# Acton                                  0.0                   0.0
# Adams-Normandie                        3.0                  42.0
# Agoura Hills                           0.0                   1.0
# Agua Dulce                             0.0                   0.0
# Alhambra                               4.0                   9.0
# Alondra Park                           0.0                   1.0
# Altadena                               2.0                   3.0
# Angeles Crest                          0.0                   0.0
# Arcadia                                1.0                   0.0
# Arleta                                 0.0                   2.0
# Arlington Heights                      2.0                   4.0
# Artesia                                3.0                   1.0
# Athens                                 0.0                   0.0
# Atwater Village                        1.0                   6.0
# Avalon                                33.0                   6.0
# Avocado Heights                        2.0                   1.0
# Azusa                                  4.0                   2.0
# Baldwin Hills/Crenshaw                 5.0                   5.0
# Baldwin Park                           3.0                   1.0
# Bel-Air                                2.0                   2.0
# Bell                                   3.0                   0.0
# Bellflower                             0.0                   0.0
# Bell Gardens                           0.0                   1.0
# Beverly Grove                          9.0                   4.0
# Beverly Hills                         15.0                   9.0
# Beverlywood                            0.0                   1.0
# Boyle Heights                          0.0                   1.0
# Bradbury                               0.0                   0.0
# Brentwood                              3.0                   6.0
# Burbank                                2.0                   9.0
# Calabasas                              0.0                   0.0
# Canoga Park                            4.0                   5.0
# Carson                                 6.0                   1.0
# Carthay                                5.0                   4.0
# Castaic                                2.0                   1.0
# Central-Alameda                        1.0                   4.0
# Century City                          12.0                   8.0
# Cerritos                               3.0                   1.0
# Charter Oak                            0.0                   0.0
# Chatsworth                             2.0                   2.0
# Chatsworth Reservoir                   2.0                   2.0
# Cheviot Hills                          0.0                   0.0
# Chinatown                              9.0                  14.0
# Citrus                                 2.0                   0.0
# Claremont                              5.0                  11.0
# Commerce                               0.0                   2.0
# Compton                                1.0                   0.0
# Covina                                 0.0                   0.0
# Cudahy                                 1.0                   0.0
# Culver City                            8.0                  14.0
#
#                         Outdoors & Recreation  Nightlife Spot  Food
# Neighborhood
# Acton                                     0.0             0.0   0.0
# Adams-Normandie                          16.0             4.0  37.0
# Agoura Hills                              8.0             0.0   6.0
# Agua Dulce                                0.0             0.0   5.0
# Alhambra                                  5.0            10.0  37.0
# Alondra Park                              4.0             0.0   0.0
# Altadena                                  6.0             7.0   9.0
# Angeles Crest                             1.0             0.0   0.0
# Arcadia                                   4.0             3.0   5.0
# Arleta                                    0.0             1.0   1.0
# Arlington Heights                         7.0             0.0   4.0
# Artesia                                   4.0             4.0  25.0
# Athens                                    1.0             0.0   3.0
# Atwater Village                           5.0             4.0  16.0
# Avalon                                   23.0             9.0  33.0
# Avocado Heights                           2.0             2.0   3.0
# Azusa                                     6.0             2.0  26.0
# Baldwin Hills/Crenshaw                    3.0             6.0  30.0
# Baldwin Park                              4.0             4.0  19.0
# Bel-Air                                   3.0             3.0   4.0
# Bell                                      2.0             3.0  16.0
# Bellflower                                3.0             1.0   3.0
# Bell Gardens                              4.0             0.0   8.0
# Beverly Grove                            18.0             5.0  16.0
# Beverly Hills                            21.0            12.0  45.0
# Beverlywood                               1.0             0.0   2.0
# Boyle Heights                             4.0             0.0   7.0
# Bradbury                                  1.0             0.0   1.0
# Brentwood                                 8.0             2.0   6.0
# Burbank                                   6.0             0.0  14.0
# Calabasas                                 0.0             0.0   0.0
# Canoga Park                               3.0             3.0  14.0
# Carson                                    1.0             0.0   3.0
# Carthay                                   6.0             4.0  18.0
# Castaic                                   0.0             3.0   8.0
# Central-Alameda                           7.0             4.0  10.0
# Century City                             20.0             8.0  75.0
# Cerritos                                  3.0             0.0   5.0
# Charter Oak                               3.0             1.0  10.0
# Chatsworth                               12.0             2.0  12.0
# Chatsworth Reservoir                     12.0             2.0  12.0
# Cheviot Hills                             8.0             0.0   4.0
# Chinatown                                 8.0             8.0  50.0
# Citrus                                    1.0             2.0   4.0
# Claremont                                 7.0            10.0  43.0
# Commerce                                  3.0             0.0  18.0
# Compton                                   0.0             0.0  16.0
# Covina                                    1.0             1.0   4.0
# Cudahy                                    5.0             1.0  11.0
# Culver City                              13.0            14.0  38.0

# %%
## mean normalized

for key in LA_Params:
    
    LA_Params[key]=LA_Params[key]/LA_Params[key].sum()
LA_Params[:50]
# Out:
#                         Travel & Transport  Arts & Entertainment  \
# Neighborhood
# Acton                             0.000000              0.000000
# Adams-Normandie                   0.005034              0.057299
# Agoura Hills                      0.000000              0.001364
# Agua Dulce                        0.000000              0.000000
# Alhambra                          0.006711              0.012278
# Alondra Park                      0.000000              0.001364
# Altadena                          0.003356              0.004093
# Angeles Crest                     0.000000              0.000000
# Arcadia                           0.001678              0.000000
# Arleta                            0.000000              0.002729
# Arlington Heights                 0.003356              0.005457
# Artesia                           0.005034              0.001364
# Athens                            0.000000              0.000000
# Atwater Village                   0.001678              0.008186
# Avalon                            0.055369              0.008186
# Avocado Heights                   0.003356              0.001364
# Azusa                             0.006711              0.002729
# Baldwin Hills/Crenshaw            0.008389              0.006821
# Baldwin Park                      0.005034              0.001364
# Bel-Air                           0.003356              0.002729
# Bell                              0.005034              0.000000
# Bellflower                        0.000000              0.000000
# Bell Gardens                      0.000000              0.001364
# Beverly Grove                     0.015101              0.005457
# Beverly Hills                     0.025168              0.012278
# Beverlywood                       0.000000              0.001364
# Boyle Heights                     0.000000              0.001364
# Bradbury                          0.000000              0.000000
# Brentwood                         0.005034              0.008186
# Burbank                           0.003356              0.012278
# Calabasas                         0.000000              0.000000
# Canoga Park                       0.006711              0.006821
# Carson                            0.010067              0.001364
# Carthay                           0.008389              0.005457
# Castaic                           0.003356              0.001364
# Central-Alameda                   0.001678              0.005457
# Century City                      0.020134              0.010914
# Cerritos                          0.005034              0.001364
# Charter Oak                       0.000000              0.000000
# Chatsworth                        0.003356              0.002729
# Chatsworth Reservoir              0.003356              0.002729
# Cheviot Hills                     0.000000              0.000000
# Chinatown                         0.015101              0.019100
# Citrus                            0.003356              0.000000
# Claremont                         0.008389              0.015007
# Commerce                          0.000000              0.002729
# Compton                           0.001678              0.000000
# Covina                            0.000000              0.000000
# Cudahy                            0.001678              0.000000
# Culver City                       0.013423              0.019100
#
#                         Outdoors & Recreation  Nightlife Spot      Food
# Neighborhood
# Acton                                0.000000        0.000000  0.000000
# Adams-Normandie                      0.013029        0.006250  0.011632
# Agoura Hills                         0.006515        0.000000  0.001886
# Agua Dulce                           0.000000        0.000000  0.001572
# Alhambra                             0.004072        0.015625  0.011632
# Alondra Park                         0.003257        0.000000  0.000000
# Altadena                             0.004886        0.010937  0.002829
# Angeles Crest                        0.000814        0.000000  0.000000
# Arcadia                              0.003257        0.004687  0.001572
# Arleta                               0.000000        0.001563  0.000314
# Arlington Heights                    0.005700        0.000000  0.001257
# Artesia                              0.003257        0.006250  0.007859
# Athens                               0.000814        0.000000  0.000943
# Atwater Village                      0.004072        0.006250  0.005030
# Avalon                               0.018730        0.014063  0.010374
# Avocado Heights                      0.001629        0.003125  0.000943
# Azusa                                0.004886        0.003125  0.008174
# Baldwin Hills/Crenshaw               0.002443        0.009375  0.009431
# Baldwin Park                         0.003257        0.006250  0.005973
# Bel-Air                              0.002443        0.004687  0.001257
# Bell                                 0.001629        0.004687  0.005030
# Bellflower                           0.002443        0.001563  0.000943
# Bell Gardens                         0.003257        0.000000  0.002515
# Beverly Grove                        0.014658        0.007812  0.005030
# Beverly Hills                        0.017101        0.018750  0.014146
# Beverlywood                          0.000814        0.000000  0.000629
# Boyle Heights                        0.003257        0.000000  0.002201
# Bradbury                             0.000814        0.000000  0.000314
# Brentwood                            0.006515        0.003125  0.001886
# Burbank                              0.004886        0.000000  0.004401
# Calabasas                            0.000000        0.000000  0.000000
# Canoga Park                          0.002443        0.004687  0.004401
# Carson                               0.000814        0.000000  0.000943
# Carthay                              0.004886        0.006250  0.005659
# Castaic                              0.000000        0.004687  0.002515
# Central-Alameda                      0.005700        0.006250  0.003144
# Century City                         0.016287        0.012500  0.023577
# Cerritos                             0.002443        0.000000  0.001572
# Charter Oak                          0.002443        0.001563  0.003144
# Chatsworth                           0.009772        0.003125  0.003772
# Chatsworth Reservoir                 0.009772        0.003125  0.003772
# Cheviot Hills                        0.006515        0.000000  0.001257
# Chinatown                            0.006515        0.012500  0.015718
# Citrus                               0.000814        0.003125  0.001257
# Claremont                            0.005700        0.015625  0.013518
# Commerce                             0.002443        0.000000  0.005659
# Compton                              0.000000        0.000000  0.005030
# Covina                               0.000814        0.001563  0.001257
# Cudahy                               0.004072        0.001563  0.003458
# Culver City                          0.010586        0.021875  0.011946

# %%
### KNN algorithm 

# set number of clusters
kclusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(LA_Params)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 0, 0, 2, 0, 2, 0, 0, 0], dtype=int32)

# %%
LA_Neighs=pd.read_csv('LA_neighborhoods_v0.3.csv')
LA_Neighs=LA_Neighs.drop(columns = ['Unnamed: 0'])
LA_Neighs[:50]
# Out:
#               Neighborhood                  Region   Latitude   Longitude
# 0                    Acton         Antelope Valley  34.480742 -118.186838
# 1          Adams-Normandie              South L.A.  34.018609 -118.287348
# 2             Agoura Hills  Santa Monica Mountains  34.147910 -118.765704
# 3               Agua Dulce        Northwest County  34.496382 -118.325635
# 4                 Alhambra      San Gabriel Valley  34.093042 -118.127060
# 5             Alondra Park               South Bay  33.890134 -118.335133
# 6                 Altadena                Verdugos  34.186316 -118.135233
# 7            Angeles Crest          Angeles Forest  34.234000 -118.183386
# 8                  Arcadia      San Gabriel Valley  34.136208 -118.040150
# 9                   Arleta     San Fernando Valley  34.241327 -118.432205
# 10       Arlington Heights            Central L.A.  34.128557 -118.152999
# 11                 Artesia               Southeast  33.869020 -118.079620
# 12                  Athens              South L.A.  33.920407 -118.279049
# 13         Atwater Village          Northeast L.A.  34.116398 -118.256464
# 14                  Avalon                  Harbor  33.342210 -118.327261
# 15         Avocado Heights      San Gabriel Valley  34.026983 -117.965433
# 16                   Azusa      San Gabriel Valley  34.133875 -117.905605
# 17  Baldwin Hills/Crenshaw              South L.A.  34.011551 -118.337374
# 18            Baldwin Park      San Gabriel Valley  34.085474 -117.961176
# 19                 Bel-Air                Westside  34.082728 -118.447980
# 20                    Bell               Southeast  33.974781 -118.186636
# 21              Bellflower               Southeast  33.882570 -118.116768
# 22            Bell Gardens               Southeast  33.969456 -118.150395
# 23           Beverly Grove            Central L.A.  34.059208 -118.411497
# 24           Beverly Hills                Westside  34.069650 -118.396306
# 25             Beverlywood                Westside  34.046633 -118.395038
# 26           Boyle Heights                Eastside  34.033166 -118.204865
# 27                Bradbury      San Gabriel Valley  34.146951 -117.970898
# 28               Brentwood                Westside  34.052140 -118.474070
# 29                 Burbank     San Fernando Valley  34.181648 -118.325855
# 30               Calabasas  Santa Monica Mountains  34.144664 -118.644097
# 31             Canoga Park     San Fernando Valley  34.201078 -118.597826
# 32                  Carson                  Harbor  33.832204 -118.251755
# 33                 Carthay            Central L.A.  34.056121 -118.373411
# 34                 Castaic        Northwest County  34.488882 -118.622866
# 35         Central-Alameda              South L.A.  34.163728 -118.314057
# 36            Century City                Westside  34.057426 -118.414727
# 37                Cerritos               Southeast  33.864429 -118.053932
# 38             Charter Oak      San Gabriel Valley  34.099799 -117.872593
# 39              Chatsworth     San Fernando Valley  34.259571 -118.602325
# 40    Chatsworth Reservoir     San Fernando Valley  34.259571 -118.602325
# 41           Cheviot Hills                Westside  34.045554 -118.409494
# 42               Chinatown            Central L.A.  34.063459 -118.236050
# 43                  Citrus      San Gabriel Valley  34.116070 -117.894807
# 44               Claremont           Pomona Valley  34.096676 -117.719778
# 45                Commerce               Southeast  34.002581 -118.156586
# 46                 Compton               Southeast  33.894927 -118.226624
# 47                  Covina      San Gabriel Valley  34.102400 -117.854865
# 48                  Cudahy               Southeast  33.962058 -118.183539
# 49             Culver City                Westside  34.021122 -118.396467

# %%
LA_Neighs.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
LA_Neighs.head()
# Out:
#    Cluster Labels     Neighborhood                  Region   Latitude  \
# 0               0            Acton         Antelope Valley  34.480742
# 1               3  Adams-Normandie              South L.A.  34.018609
# 2               0     Agoura Hills  Santa Monica Mountains  34.147910
# 3               0       Agua Dulce        Northwest County  34.496382
# 4               2         Alhambra      San Gabriel Valley  34.093042
#
#     Longitude
# 0 -118.186838
# 1 -118.287348
# 2 -118.765704
# 3 -118.325635
# 4 -118.127060

# %% [markdown]
# ## Results

# %%
# create map
map_clusters = folium.Map(location=[LAlatitude, LAlongitude], zoom_start=11, width=800, height=900)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
cluster_counter=0
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(LA_Neighs['Latitude'], LA_Neighs['Longitude'], LA_Neighs['Neighborhood'], LA_Neighs['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    cluster_counter += 1
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Conclusion
