# %%
# The code was removed by Watson Studio for sharing.

# %%
# !pip install --user folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 13.7MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.10.1

# %%
### Importing libraries 

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import re

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#  # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import bs4 as bs

import urllib.request

import requests

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails: hidden

# %%
source = urllib.request.urlopen('http://maps.latimes.com/neighborhoods/neighborhood/list/').read()
soup=bs.BeautifulSoup(source, 'lxml')

table = soup.find('table')

table_rows = table.find_all('tr')

ls = []
for tr in table_rows:
    td = tr.find_all('a')
    row = [tr.text.strip() for tr in td]
    ls.append(row)
    
LA_neighs = pd.DataFrame(ls, columns = ['Neighborhood','Region'])

LA_neighs=LA_neighs.drop(LA_neighs.index[0])

LA_neighs.tail()

# %%
latitude = []
longitude = []

for name in LA_neighs['Neighborhood']:
    try:
        address = str(name)+", Los Angeles, California"
        geolocator = Nominatim(user_agent="LA_explorer")
        location = geolocator.geocode(address)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except:
        latitude.append(None)
        longitude.append(None)

LA_neighs['Latitude'] = latitude
LA_neighs['Longitude'] = longitude

# %%
LA_neighs[0:50]
# Out:
#               Neighborhood                  Region   Latitude   Longitude
# 0                    Acton         Antelope Valley  34.480742 -118.186838
# 1          Adams-Normandie              South L.A.  34.018609 -118.287348
# 2             Agoura Hills  Santa Monica Mountains  34.147910 -118.765704
# 3               Agua Dulce        Northwest County  34.496382 -118.325635
# 4                 Alhambra      San Gabriel Valley  34.093042 -118.127060
# 5             Alondra Park               South Bay  33.890134 -118.335133
# 6                 Altadena                Verdugos  34.186316 -118.135233
# 7            Angeles Crest          Angeles Forest  34.234000 -118.183386
# 8                  Arcadia      San Gabriel Valley  34.136207 -118.040150
# 9                   Arleta     San Fernando Valley  34.241327 -118.432205
# 10       Arlington Heights            Central L.A.  34.128557 -118.152999
# 11                 Artesia               Southeast  33.869020 -118.079620
# 12                  Athens              South L.A.  33.920407 -118.279049
# 13         Atwater Village          Northeast L.A.  34.116398 -118.256464
# 14                  Avalon                  Harbor  33.342210 -118.327261
# 15         Avocado Heights      San Gabriel Valley  34.026983 -117.965433
# 16                   Azusa      San Gabriel Valley  34.133875 -117.905605
# 17  Baldwin Hills/Crenshaw              South L.A.  34.011551 -118.337374
# 18            Baldwin Park      San Gabriel Valley  34.085474 -117.961176
# 19                 Bel-Air                Westside  34.082728 -118.447980
# 20                    Bell               Southeast  33.974781 -118.186636
# 21              Bellflower               Southeast  33.882570 -118.116768
# 22            Bell Gardens               Southeast  33.969456 -118.150395
# 23           Beverly Grove            Central L.A.  34.059208 -118.411497
# 24           Beverly Hills                Westside  34.069650 -118.396306
# 25             Beverlywood                Westside  34.046633 -118.395038
# 26           Boyle Heights                Eastside  34.033166 -118.204865
# 27                Bradbury      San Gabriel Valley  34.146951 -117.970898
# 28               Brentwood                Westside  34.052140 -118.474070
# 29                 Burbank     San Fernando Valley  34.181648 -118.325855
# 30               Calabasas  Santa Monica Mountains  34.144664 -118.644097
# 31             Canoga Park     San Fernando Valley  34.201078 -118.597826
# 32                  Carson                  Harbor  33.832204 -118.251755
# 33                 Carthay            Central L.A.  34.056121 -118.373411
# 34                 Castaic        Northwest County  34.488882 -118.622866
# 35         Central-Alameda              South L.A.  34.163728 -118.314057
# 36            Century City                Westside  34.057426 -118.414727
# 37                Cerritos               Southeast  33.864429 -118.053932
# 38             Charter Oak      San Gabriel Valley  34.099799 -117.872593
# 39              Chatsworth     San Fernando Valley  34.259571 -118.602325
# 40    Chatsworth Reservoir     San Fernando Valley  34.259571 -118.602325
# 41           Cheviot Hills                Westside  34.045554 -118.409494
# 42               Chinatown            Central L.A.  34.063459 -118.236050
# 43                  Citrus      San Gabriel Valley  34.116070 -117.894807
# 44               Claremont           Pomona Valley  34.096676 -117.719779
# 45                Commerce               Southeast  34.002581 -118.156586
# 46                 Compton               Southeast  33.894927 -118.226624
# 47                  Covina      San Gabriel Valley  34.102400 -117.854865
# 48                  Cudahy               Southeast  33.962058 -118.183539
# 49             Culver City                Westside  34.021122 -118.396467

# %%
### Saving data to csv
project.save_data(data=LA_neighs.to_csv(index=False),file_name='LA_neighborhoods_v0.3.csv',overwrite=True)
# Out:
# {'file_name': 'LA_neighborhoods_v0.3.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'datasciencecapstone-donotdelete-pr-sodywh9vtibs6d',
#  'asset_id': '8df33260-49a9-446e-8a58-818c80d9ab3d'}

# %%
#Getting csv file and loading as pandas datafarme
LA_neighs=pd.read_csv(project.get_file('LA_neighborhoods_v0.3.csv'))

LA_neighs.head(50)
# Out:
#               Neighborhood                  Region   Latitude   Longitude
# 0                    Acton         Antelope Valley  34.480742 -118.186838
# 1          Adams-Normandie              South L.A.  34.018609 -118.287348
# 2             Agoura Hills  Santa Monica Mountains  34.147910 -118.765704
# 3               Agua Dulce        Northwest County  34.496382 -118.325635
# 4                 Alhambra      San Gabriel Valley  34.093042 -118.127060
# 5             Alondra Park               South Bay  33.890134 -118.335133
# 6                 Altadena                Verdugos  34.186316 -118.135233
# 7            Angeles Crest          Angeles Forest  34.234000 -118.183386
# 8                  Arcadia      San Gabriel Valley  34.136208 -118.040150
# 9                   Arleta     San Fernando Valley  34.241327 -118.432205
# 10       Arlington Heights            Central L.A.  34.128557 -118.152999
# 11                 Artesia               Southeast  33.869020 -118.079620
# 12                  Athens              South L.A.  33.920407 -118.279049
# 13         Atwater Village          Northeast L.A.  34.116398 -118.256464
# 14                  Avalon                  Harbor  33.342210 -118.327261
# 15         Avocado Heights      San Gabriel Valley  34.026983 -117.965433
# 16                   Azusa      San Gabriel Valley  34.133875 -117.905605
# 17  Baldwin Hills/Crenshaw              South L.A.  34.011551 -118.337374
# 18            Baldwin Park      San Gabriel Valley  34.085474 -117.961176
# 19                 Bel-Air                Westside  34.082728 -118.447980
# 20                    Bell               Southeast  33.974781 -118.186636
# 21              Bellflower               Southeast  33.882570 -118.116768
# 22            Bell Gardens               Southeast  33.969456 -118.150395
# 23           Beverly Grove            Central L.A.  34.059208 -118.411497
# 24           Beverly Hills                Westside  34.069650 -118.396306
# 25             Beverlywood                Westside  34.046633 -118.395038
# 26           Boyle Heights                Eastside  34.033166 -118.204865
# 27                Bradbury      San Gabriel Valley  34.146951 -117.970898
# 28               Brentwood                Westside  34.052140 -118.474070
# 29                 Burbank     San Fernando Valley  34.181648 -118.325855
# 30               Calabasas  Santa Monica Mountains  34.144664 -118.644097
# 31             Canoga Park     San Fernando Valley  34.201078 -118.597826
# 32                  Carson                  Harbor  33.832204 -118.251755
# 33                 Carthay            Central L.A.  34.056121 -118.373411
# 34                 Castaic        Northwest County  34.488882 -118.622866
# 35         Central-Alameda              South L.A.  34.163728 -118.314057
# 36            Century City                Westside  34.057426 -118.414727
# 37                Cerritos               Southeast  33.864429 -118.053932
# 38             Charter Oak      San Gabriel Valley  34.099799 -117.872593
# 39              Chatsworth     San Fernando Valley  34.259571 -118.602325
# 40    Chatsworth Reservoir     San Fernando Valley  34.259571 -118.602325
# 41           Cheviot Hills                Westside  34.045554 -118.409494
# 42               Chinatown            Central L.A.  34.063459 -118.236050
# 43                  Citrus      San Gabriel Valley  34.116070 -117.894807
# 44               Claremont           Pomona Valley  34.096676 -117.719778
# 45                Commerce               Southeast  34.002581 -118.156586
# 46                 Compton               Southeast  33.894927 -118.226624
# 47                  Covina      San Gabriel Valley  34.102400 -117.854865
# 48                  Cudahy               Southeast  33.962058 -118.183539
# 49             Culver City                Westside  34.021122 -118.396467

# %%
address = 'Los Angeles, CA'

geolocator = Nominatim(user_agent="LA_explorer")
location = geolocator.geocode(address)
LAlatitude = location.latitude
LAlongitude = location.longitude
print('The geograpical coordinate of Los Angeles are {}, {}.'.format(LAlatitude, LAlongitude))
# Out:
# The geograpical coordinate of Los Angeles are 34.0536909, -118.2427666.

# %%
# create map of LA using latitude and longitude values
map_LA = folium.Map(location=[LAlatitude, LAlongitude], zoom_start=11, width=800, height=600)

counter1=0

# add markers to map
for lat, lng, borough, neighborhood in zip(LA_neighs['Latitude'], LA_neighs['Longitude'], LA_neighs['Neighborhood'], LA_neighs['Region']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_LA)  
    counter1+=1
map_LA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
catIds={'Travel & Transport': '4d4b7105d754a06379d81259', 
        'Arts & Entertainment': '4d4b7104d754a06370d81259',
        'Outdoors & Recreation':'4d4b7105d754a06377d81259',
        'Nightlife Spot':'4d4b7105d754a06376d81259',
        'Food':'4d4b7105d754a06374d81259'
       }
catIds
# Out:
# {'Travel & Transport': '4d4b7105d754a06379d81259',
#  'Arts & Entertainment': '4d4b7104d754a06370d81259',
#  'Outdoors & Recreation': '4d4b7105d754a06377d81259',
#  'Nightlife Spot': '4d4b7105d754a06376d81259',
#  'Food': '4d4b7105d754a06374d81259'}

# %%
for key in catIds:
    print(key)
    print(catIds[key])
# Out:
# Travel & Transport
# 4d4b7105d754a06379d81259
# Arts & Entertainment
# 4d4b7104d754a06370d81259
# Outdoors & Recreation
# 4d4b7105d754a06377d81259
# Nightlife Spot
# 4d4b7105d754a06376d81259
# Food
# 4d4b7105d754a06374d81259

# %%
def getNearbyVenues(names, latitudes, longitudes, categoryIds, radius, limit):
    venues_dict={}
    venues_list=[]
    LIMIT = limit # limit of number of venues returned by Foursquare API
    radius = radius # define radius
    for key in categoryIds:
        
        for name, lat, lng in zip(names, latitudes, longitudes):
            
            categoryId = categoryIds[key]
            
            url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            categoryId,
            LIMIT)
            
            # make the GET request
            results = requests.get(url).json()["response"]['groups'][0]['items']
        
            # return only relevant information for each nearby venue
            venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
            
        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
        
        venues_dict[key] = nearby_venues
    
    return(venues_dict)

# %%
venues_dict = getNearbyVenues(LA_neighs['Neighborhood'], LA_neighs['Latitude'], LA_neighs['Longitude'], categoryIds = catIds, radius = 500, limit = 100)

# %%
venues_dict['Travel & Transport']
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Adams-Normandie              34.018609             -118.287348
# 1       Adams-Normandie              34.018609             -118.287348
# 2       Adams-Normandie              34.018609             -118.287348
# 3              Alhambra              34.093042             -118.127060
# 4              Alhambra              34.093042             -118.127060
# 5              Alhambra              34.093042             -118.127060
# 6              Alhambra              34.093042             -118.127060
# 7              Altadena              34.186316             -118.135233
# 8              Altadena              34.186316             -118.135233
# 9               Arcadia              34.136208             -118.040150
# 10    Arlington Heights              34.128557             -118.152999
# 11    Arlington Heights              34.128557             -118.152999
# 12              Artesia              33.869020             -118.079620
# 13              Artesia              33.869020             -118.079620
# 14              Artesia              33.869020             -118.079620
# 15      Atwater Village              34.116398             -118.256464
# 16               Avalon              33.342210             -118.327261
# 17               Avalon              33.342210             -118.327261
# 18               Avalon              33.342210             -118.327261
# 19               Avalon              33.342210             -118.327261
# 20               Avalon              33.342210             -118.327261
# 21               Avalon              33.342210             -118.327261
# 22               Avalon              33.342210             -118.327261
# 23               Avalon              33.342210             -118.327261
# 24               Avalon              33.342210             -118.327261
# 25               Avalon              33.342210             -118.327261
# 26               Avalon              33.342210             -118.327261
# 27               Avalon              33.342210             -118.327261
# 28               Avalon              33.342210             -118.327261
# 29               Avalon              33.342210             -118.327261
# ..                  ...                    ...                     ...
# 567    West Los Angeles              34.046399             -118.448135
# 568    West Los Angeles              34.046399             -118.448135
# 569    West Los Angeles              34.046399             -118.448135
# 570    West Los Angeles              34.046399             -118.448135
# 571    West Los Angeles              34.046399             -118.448135
# 572  West Puente Valley              34.049858             -117.964629
# 573  West Puente Valley              34.049858             -117.964629
# 574      West San Dimas              34.106676             -117.806726
# 575            Westwood              34.066895             -118.439945
# 576            Westwood              34.066895             -118.439945
# 577            Westwood              34.066895             -118.439945
# 578            Westwood              34.066895             -118.439945
# 579            Westwood              34.066895             -118.439945
# 580            Westwood              34.066895             -118.439945
# 581            Westwood              34.066895             -118.439945
# 582            Westwood              34.066895             -118.439945
# 583          Wilmington              33.780018             -118.262571
# 584          Wilmington              33.780018             -118.262571
# 585          Wilmington              33.780018             -118.262571
# 586      Windsor Square              34.072593             -118.320810
# 587      Windsor Square              34.072593             -118.320810
# 588      Windsor Square              34.072593             -118.320810
# 589            Winnetka              34.205883             -118.570934
# 590            Winnetka              34.205883             -118.570934
# 591      Woodland Hills              34.168436             -118.605838
# 592      Woodland Hills              34.168436             -118.605838
# 593      Woodland Hills              34.168436             -118.605838
# 594      Woodland Hills              34.168436             -118.605838
# 595      Woodland Hills              34.168436             -118.605838
# 596      Woodland Hills              34.168436             -118.605838
#
#                                                Venue  Venue Latitude  \
# 0             Metro Rail - Expo Park/USC Station (E)       34.018237
# 1     Natural History Museum (NHM) Metro Bus 102/550       34.018072
# 2              Metro Rail - Expo/Vermont Station (E)       34.018241
# 3                                    Avis Car Rental       34.091506
# 4                               Days Inn Alhambra CA       34.095091
# 5                                     Act Green Line       34.095480
# 6                                     ACT Green Line       34.092469
# 7                                Open Trails E-Bikes       34.187506
# 8                Santa Rosa Avenue & Mariposa Street       34.189353
# 9                                The Santa Anita Inn       34.139397
# 10                             Enterprise Rent-A-Car       34.127690
# 11                          RR XING @ E. Glenarm St.       34.127839
# 12                                       Rodeway Inn       33.872479
# 13                         Days Inn & Suites Artesia       33.871673
# 14                              Harrah's Bus Pick Up       33.871667
# 15                            Casitas Hotel For Cats       34.120225
# 16                               Hotel Vista Del Mar       33.343513
# 17                                    Pavilion Hotel       33.343052
# 18                               Catalina Island Inn       33.343989
# 19                                   Hotel Metropole       33.344593
# 20                                  Hotel St. Lauren       33.342637
# 21                             Hotel Villa Portofino       33.345011
# 22                                     Hermosa Hotel       33.343753
# 23                                     Hotel Atwater       33.343406
# 24                                    Hotel Catalina       33.344732
# 25                                   Snug Harbor Inn       33.343733
# 26                                     The Edgewater       33.343485
# 27                                 Catalina Cottages       33.343700
# 28                           Hermosa Hotel Cottage C       33.343667
# 29                                  Pigs Fly Cottage       33.340970
# ..                                               ...             ...
# 567                        I-405 & Santa Monica Blvd       34.046966
# 568                                 Bus Stop #1 & #4       34.046150
# 569                                 I-405 / Ohio Ave       34.049317
# 570                              Culver City Rapid 6       34.047361
# 571                       Metro 734 Westwood Gateway       34.047754
# 572                         Cargo Mover In La Puente       34.050882
# 573                                         Das Boot       34.053655
# 574                        Foothill Transit Bus Stop       34.107001
# 575               W Los Angeles - West Beverly Hills       34.063275
# 576                              UCLA Tiverton House       34.063081
# 577                               Hilgard & Le Conte       34.064465
# 578                            Hilgard and Westholme       34.069381
# 579         UCLA Hilgard Bus Terminal (Big Blue Bus)       34.069440
# 580                                         Bus Stop       34.063889
# 581      UCLA BruinBus Stop: Gonda Research Facility       34.067074
# 582                              Hilgard House Hotel       34.063232
# 583                                 Ambassador Hotel       33.780102
# 584                                  Regency USA Inc       33.780546
# 585                                            sleep       33.780300
# 586                           Independent taxi #1124       34.076259
# 587                                     Fire Hydrant       34.068864
# 588  Metro Bus - 16/17 (S Larchmont Blvd & W 3rd St)       34.068987
# 589                                      Rodeway Inn       34.205285
# 590                                    Starlight Inn       34.205084
# 591                  Best Western Woodland Hills Inn       34.167618
# 592                           Topanga/Woodland Hills       34.169685
# 593     Topanga Canyon Boulevard & Ventura Boulevard       34.168519
# 594                               Bus Stop Metro 150       34.168772
# 595                                 Glendevon Motors       34.167908
# 596                       Knights Inn Woodland Hills       34.168148
#
#      Venue Longitude            Venue Category
# 0        -118.286094        Light Rail Station
# 1        -118.288654                  Bus Stop
# 2        -118.291541        Light Rail Station
# 3        -118.124138       Rental Car Location
# 4        -118.128615                     Hotel
# 5        -118.126460                  Bus Stop
# 6        -118.132307                  Bus Stop
# 7        -118.133583  Bike Rental / Bike Share
# 8        -118.136372              Intersection
# 9        -118.036965                     Hotel
# 10       -118.150102       Rental Car Location
# 11       -118.148203              Intersection
# 12       -118.080209                     Hotel
# 13       -118.081303                     Hotel
# 14       -118.081999                  Bus Stop
# 15       -118.256538                     Hotel
# 16       -118.325523                     Hotel
# 17       -118.324963                     Hotel
# 18       -118.327253                     Hotel
# 19       -118.327165                     Hotel
# 20       -118.328330                     Hotel
# 21       -118.327119                     Hotel
# 22       -118.327312                     Hotel
# 23       -118.326634                     Hotel
# 24       -118.327800                     Hotel
# 25       -118.326164           Bed & Breakfast
# 26       -118.325770                     Hotel
# 27       -118.327266                     Hotel
# 28       -118.327648                     Hotel
# 29       -118.327645                     Hotel
# ..               ...                       ...
# 567      -118.446674              Intersection
# 568      -118.449880               Bus Station
# 569      -118.448474              Intersection
# 570      -118.444253             Moving Target
# 571      -118.444278                  Bus Stop
# 572      -117.961450             Moving Target
# 573      -117.962523             Boat or Ferry
# 574      -117.806726               Bus Station
# 575      -118.440950                     Hotel
# 576      -118.442145                     Hotel
# 577      -118.440886                  Bus Stop
# 578      -118.439117               Bus Station
# 579      -118.439102               Bus Station
# 580      -118.439519               Bus Station
# 581      -118.444609               Bus Station
# 582      -118.441630                     Hotel
# 583      -118.265099                     Hotel
# 584      -118.258910       Rental Car Location
# 585      -118.267900                     Hotel
# 586      -118.319382             Moving Target
# 587      -118.318573            Airport Lounge
# 588      -118.323378                  Bus Stop
# 589      -118.571380                     Motel
# 590      -118.571363                     Motel
# 591      -118.603206                     Hotel
# 592      -118.605958              Intersection
# 593      -118.605850              Intersection
# 594      -118.605629                  Bus Stop
# 595      -118.606049       Rental Car Location
# 596      -118.601053                     Hotel
#
# [597 rows x 7 columns]

# %%
venues_dict['Arts & Entertainment']
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Adams-Normandie              34.018609             -118.287348
# 1       Adams-Normandie              34.018609             -118.287348
# 2       Adams-Normandie              34.018609             -118.287348
# 3              Alhambra              34.093042             -118.127060
# 4              Alhambra              34.093042             -118.127060
# 5              Alhambra              34.093042             -118.127060
# 6              Alhambra              34.093042             -118.127060
# 7              Altadena              34.186316             -118.135233
# 8              Altadena              34.186316             -118.135233
# 9               Arcadia              34.136208             -118.040150
# 10    Arlington Heights              34.128557             -118.152999
# 11    Arlington Heights              34.128557             -118.152999
# 12              Artesia              33.869020             -118.079620
# 13              Artesia              33.869020             -118.079620
# 14              Artesia              33.869020             -118.079620
# 15      Atwater Village              34.116398             -118.256464
# 16               Avalon              33.342210             -118.327261
# 17               Avalon              33.342210             -118.327261
# 18               Avalon              33.342210             -118.327261
# 19               Avalon              33.342210             -118.327261
# 20               Avalon              33.342210             -118.327261
# 21               Avalon              33.342210             -118.327261
# 22               Avalon              33.342210             -118.327261
# 23               Avalon              33.342210             -118.327261
# 24               Avalon              33.342210             -118.327261
# 25               Avalon              33.342210             -118.327261
# 26               Avalon              33.342210             -118.327261
# 27               Avalon              33.342210             -118.327261
# 28               Avalon              33.342210             -118.327261
# 29               Avalon              33.342210             -118.327261
# ...                 ...                    ...                     ...
# 1305           Westmont              33.941403             -118.302296
# 1306     West San Dimas              34.106676             -117.806726
# 1307     West San Dimas              34.106676             -117.806726
# 1308     West San Dimas              34.106676             -117.806726
# 1309     West San Dimas              34.106676             -117.806726
# 1310           Westwood              34.066895             -118.439945
# 1311           Westwood              34.066895             -118.439945
# 1312           Westwood              34.066895             -118.439945
# 1313           Westwood              34.066895             -118.439945
# 1314           Westwood              34.066895             -118.439945
# 1315           Westwood              34.066895             -118.439945
# 1316           Westwood              34.066895             -118.439945
# 1317           Westwood              34.066895             -118.439945
# 1318           Whittier              33.970878             -118.030840
# 1319           Whittier              33.970878             -118.030840
# 1320           Whittier              33.970878             -118.030840
# 1321           Whittier              33.970878             -118.030840
# 1322           Whittier              33.970878             -118.030840
# 1323           Whittier              33.970878             -118.030840
# 1324   Whittier Narrows              34.021068             -118.069073
# 1325         Wilmington              33.780018             -118.262571
# 1326         Wilmington              33.780018             -118.262571
# 1327         Wilmington              33.780018             -118.262571
# 1328         Wilmington              33.780018             -118.262571
# 1329     Windsor Square              34.072593             -118.320810
# 1330     Windsor Square              34.072593             -118.320810
# 1331     Windsor Square              34.072593             -118.320810
# 1332     Windsor Square              34.072593             -118.320810
# 1333     Woodland Hills              34.168436             -118.605838
# 1334     Woodland Hills              34.168436             -118.605838
#
#                                                Venue  Venue Latitude  \
# 0             Metro Rail - Expo Park/USC Station (E)       34.018237
# 1     Natural History Museum (NHM) Metro Bus 102/550       34.018072
# 2              Metro Rail - Expo/Vermont Station (E)       34.018241
# 3                                    Avis Car Rental       34.091506
# 4                               Days Inn Alhambra CA       34.095091
# 5                                     Act Green Line       34.095480
# 6                                     ACT Green Line       34.092469
# 7                                Open Trails E-Bikes       34.187506
# 8                Santa Rosa Avenue & Mariposa Street       34.189353
# 9                                The Santa Anita Inn       34.139397
# 10                             Enterprise Rent-A-Car       34.127690
# 11                          RR XING @ E. Glenarm St.       34.127839
# 12                                       Rodeway Inn       33.872479
# 13                         Days Inn & Suites Artesia       33.871673
# 14                              Harrah's Bus Pick Up       33.871667
# 15                            Casitas Hotel For Cats       34.120225
# 16                               Hotel Vista Del Mar       33.343513
# 17                                    Pavilion Hotel       33.343052
# 18                               Catalina Island Inn       33.343989
# 19                                   Hotel Metropole       33.344593
# 20                                  Hotel St. Lauren       33.342637
# 21                             Hotel Villa Portofino       33.345011
# 22                                     Hermosa Hotel       33.343753
# 23                                     Hotel Atwater       33.343406
# 24                                    Hotel Catalina       33.344732
# 25                                   Snug Harbor Inn       33.343733
# 26                                     The Edgewater       33.343485
# 27                                 Catalina Cottages       33.343700
# 28                           Hermosa Hotel Cottage C       33.343667
# 29                                  Pigs Fly Cottage       33.340970
# ...                                              ...             ...
# 1305                   Washington Prep Dream Theater       33.937984
# 1306                     San Dimas Music in the Park       34.108462
# 1307                        Pacific Railroad Society       34.106332
# 1308                            Pacific Train Museum       34.106368
# 1309                             Third Street Cinema       34.109396
# 1310                                            KCIS       34.068716
# 1311                                UCLA Planetarium       34.069356
# 1312       Living Room, W Hotel - West Beverly Hills       34.063251
# 1313                                      Showbizzle       34.063261
# 1314                      Semel Institute Auditorium       34.065477
# 1315                         UCLA Jan Popper Theater       34.071160
# 1316                             10526 Edgeley Place       34.069708
# 1317                                       Ecochella       34.070388
# 1318                         Whittier Center Theatre       33.972578
# 1319                      Whittier Community Theater       33.972692
# 1320                           TrainTrackStudios.com       33.969180
# 1321                     Whittier Community Services       33.973158
# 1322                         Whittier Center Theater       33.973347
# 1323                            Whittier Art Gallery       33.967163
# 1324              ángela's & louisa's rivera riviera       34.018159
# 1325                                ELLAS Collective       33.779441
# 1326                   Wilmington Empowerment Center       33.777884
# 1327                         Red Video and Boutiquet       33.780300
# 1328                                       Slanguage       33.784048
# 1329               Ai Weiwei : Life Cycle Exhibition       34.073204
# 1330                                The Rave'n Haven       34.074385
# 1331                               The Heart Gallery       34.073546
# 1332                                 Larchmont Clock       34.074990
# 1333                                 George Houstenn       34.169724
# 1334                                Artist's Enclave       34.168079
#
#       Venue Longitude            Venue Category
# 0         -118.286094        Light Rail Station
# 1         -118.288654                  Bus Stop
# 2         -118.291541        Light Rail Station
# 3         -118.124138       Rental Car Location
# 4         -118.128615                     Hotel
# 5         -118.126460                  Bus Stop
# 6         -118.132307                  Bus Stop
# 7         -118.133583  Bike Rental / Bike Share
# 8         -118.136372              Intersection
# 9         -118.036965                     Hotel
# 10        -118.150102       Rental Car Location
# 11        -118.148203              Intersection
# 12        -118.080209                     Hotel
# 13        -118.081303                     Hotel
# 14        -118.081999                  Bus Stop
# 15        -118.256538                     Hotel
# 16        -118.325523                     Hotel
# 17        -118.324963                     Hotel
# 18        -118.327253                     Hotel
# 19        -118.327165                     Hotel
# 20        -118.328330                     Hotel
# 21        -118.327119                     Hotel
# 22        -118.327312                     Hotel
# 23        -118.326634                     Hotel
# 24        -118.327800                     Hotel
# 25        -118.326164           Bed & Breakfast
# 26        -118.325770                     Hotel
# 27        -118.327266                     Hotel
# 28        -118.327648                     Hotel
# 29        -118.327645                     Hotel
# ...               ...                       ...
# 1305      -118.303868     Performing Arts Venue
# 1306      -117.805203               Music Venue
# 1307      -117.809759                    Museum
# 1308      -117.809830            History Museum
# 1309      -117.806799             Movie Theater
# 1310      -118.442622            Science Museum
# 1311      -118.442587               Planetarium
# 1312      -118.440906               Music Venue
# 1313      -118.441418      Arts & Entertainment
# 1314      -118.444546     Performing Arts Venue
# 1315      -118.440458             Movie Theater
# 1316      -118.435995               Music Venue
# 1317      -118.443284               Music Venue
# 1318      -118.032494             Indie Theater
# 1319      -118.034610              Concert Hall
# 1320      -118.034720               Art Gallery
# 1321      -118.034690               Comedy Club
# 1322      -118.034615              Concert Hall
# 1323      -118.032972               Art Gallery
# 1324      -118.067580                Salsa Club
# 1325      -118.262418               Art Gallery
# 1326      -118.262357               Art Gallery
# 1327      -118.258003             Movie Theater
# 1328      -118.262731               Art Gallery
# 1329      -118.322606                    Museum
# 1330      -118.322359               Music Venue
# 1331      -118.323762               Art Gallery
# 1332      -118.323680                Public Art
# 1333      -118.604019       Indie Movie Theater
# 1334      -118.601721               Art Gallery
#
# [1335 rows x 7 columns]

# %%
import re

for key in venues_dict:
    key1=re.sub('[^A-Za-z0-9&]+ ', '', key)
    key1=re.sub('\W+','', key1)
    project.save_data(str(key1)+".csv", venues_dict[key].to_csv(), overwrite = True)

# %%
for key in catIds:
    key1=re.sub('[^A-Za-z0-9&]+ ', '', key)
    key1=re.sub('\W+','', key1)
    LA_VENUES[key]=pd.read_csv(project.get_file(str(key1)+'.csv'))

# %%
for key in LA_VENUES:
    print(key)
    print(LA_VENUES[key].shape)
# Out:
# Travel & Transport
# (597, 8)
# Arts & Entertainment
# (1335, 8)
# Outdoors & Recreation
# (2568, 8)
# Nightlife Spot
# (3214, 8)
# Food
# (6429, 8)

# %%
LA_VENUES['Travel & Transport']
# Out:
#      Unnamed: 0        Neighborhood  Neighborhood Latitude  \
# 0             0     Adams-Normandie              34.018609
# 1             1     Adams-Normandie              34.018609
# 2             2     Adams-Normandie              34.018609
# 3             3            Alhambra              34.093042
# 4             4            Alhambra              34.093042
# 5             5            Alhambra              34.093042
# 6             6            Alhambra              34.093042
# 7             7            Altadena              34.186316
# 8             8            Altadena              34.186316
# 9             9             Arcadia              34.136208
# 10           10   Arlington Heights              34.128557
# 11           11   Arlington Heights              34.128557
# 12           12             Artesia              33.869020
# 13           13             Artesia              33.869020
# 14           14             Artesia              33.869020
# 15           15     Atwater Village              34.116398
# 16           16              Avalon              33.342210
# 17           17              Avalon              33.342210
# 18           18              Avalon              33.342210
# 19           19              Avalon              33.342210
# 20           20              Avalon              33.342210
# 21           21              Avalon              33.342210
# 22           22              Avalon              33.342210
# 23           23              Avalon              33.342210
# 24           24              Avalon              33.342210
# 25           25              Avalon              33.342210
# 26           26              Avalon              33.342210
# 27           27              Avalon              33.342210
# 28           28              Avalon              33.342210
# 29           29              Avalon              33.342210
# ..          ...                 ...                    ...
# 567         567    West Los Angeles              34.046399
# 568         568    West Los Angeles              34.046399
# 569         569    West Los Angeles              34.046399
# 570         570    West Los Angeles              34.046399
# 571         571    West Los Angeles              34.046399
# 572         572  West Puente Valley              34.049858
# 573         573  West Puente Valley              34.049858
# 574         574      West San Dimas              34.106676
# 575         575            Westwood              34.066895
# 576         576            Westwood              34.066895
# 577         577            Westwood              34.066895
# 578         578            Westwood              34.066895
# 579         579            Westwood              34.066895
# 580         580            Westwood              34.066895
# 581         581            Westwood              34.066895
# 582         582            Westwood              34.066895
# 583         583          Wilmington              33.780018
# 584         584          Wilmington              33.780018
# 585         585          Wilmington              33.780018
# 586         586      Windsor Square              34.072593
# 587         587      Windsor Square              34.072593
# 588         588      Windsor Square              34.072593
# 589         589            Winnetka              34.205883
# 590         590            Winnetka              34.205883
# 591         591      Woodland Hills              34.168436
# 592         592      Woodland Hills              34.168436
# 593         593      Woodland Hills              34.168436
# 594         594      Woodland Hills              34.168436
# 595         595      Woodland Hills              34.168436
# 596         596      Woodland Hills              34.168436
#
#      Neighborhood Longitude                                            Venue  \
# 0               -118.287348           Metro Rail - Expo Park/USC Station (E)
# 1               -118.287348   Natural History Museum (NHM) Metro Bus 102/550
# 2               -118.287348            Metro Rail - Expo/Vermont Station (E)
# 3               -118.127060                                  Avis Car Rental
# 4               -118.127060                             Days Inn Alhambra CA
# 5               -118.127060                                   Act Green Line
# 6               -118.127060                                   ACT Green Line
# 7               -118.135233                              Open Trails E-Bikes
# 8               -118.135233              Santa Rosa Avenue & Mariposa Street
# 9               -118.040150                              The Santa Anita Inn
# 10              -118.152999                            Enterprise Rent-A-Car
# 11              -118.152999                         RR XING @ E. Glenarm St.
# 12              -118.079620                                      Rodeway Inn
# 13              -118.079620                        Days Inn & Suites Artesia
# 14              -118.079620                             Harrah's Bus Pick Up
# 15              -118.256464                           Casitas Hotel For Cats
# 16              -118.327261                              Hotel Vista Del Mar
# 17              -118.327261                                   Pavilion Hotel
# 18              -118.327261                              Catalina Island Inn
# 19              -118.327261                                  Hotel Metropole
# 20              -118.327261                                 Hotel St. Lauren
# 21              -118.327261                            Hotel Villa Portofino
# 22              -118.327261                                    Hermosa Hotel
# 23              -118.327261                                    Hotel Atwater
# 24              -118.327261                                   Hotel Catalina
# 25              -118.327261                                  Snug Harbor Inn
# 26              -118.327261                                    The Edgewater
# 27              -118.327261                                Catalina Cottages
# 28              -118.327261                          Hermosa Hotel Cottage C
# 29              -118.327261                                 Pigs Fly Cottage
# ..                      ...                                              ...
# 567             -118.448135                        I-405 & Santa Monica Blvd
# 568             -118.448135                                 Bus Stop #1 & #4
# 569             -118.448135                                 I-405 / Ohio Ave
# 570             -118.448135                              Culver City Rapid 6
# 571             -118.448135                       Metro 734 Westwood Gateway
# 572             -117.964629                         Cargo Mover In La Puente
# 573             -117.964629                                         Das Boot
# 574             -117.806726                        Foothill Transit Bus Stop
# 575             -118.439945               W Los Angeles - West Beverly Hills
# 576             -118.439945                              UCLA Tiverton House
# 577             -118.439945                               Hilgard & Le Conte
# 578             -118.439945                            Hilgard and Westholme
# 579             -118.439945         UCLA Hilgard Bus Terminal (Big Blue Bus)
# 580             -118.439945                                         Bus Stop
# 581             -118.439945      UCLA BruinBus Stop: Gonda Research Facility
# 582             -118.439945                              Hilgard House Hotel
# 583             -118.262571                                 Ambassador Hotel
# 584             -118.262571                                  Regency USA Inc
# 585             -118.262571                                            sleep
# 586             -118.320810                           Independent taxi #1124
# 587             -118.320810                                     Fire Hydrant
# 588             -118.320810  Metro Bus - 16/17 (S Larchmont Blvd & W 3rd St)
# 589             -118.570934                                      Rodeway Inn
# 590             -118.570934                                    Starlight Inn
# 591             -118.605838                  Best Western Woodland Hills Inn
# 592             -118.605838                           Topanga/Woodland Hills
# 593             -118.605838     Topanga Canyon Boulevard & Ventura Boulevard
# 594             -118.605838                               Bus Stop Metro 150
# 595             -118.605838                                 Glendevon Motors
# 596             -118.605838                       Knights Inn Woodland Hills
#
#      Venue Latitude  Venue Longitude            Venue Category
# 0         34.018237      -118.286094        Light Rail Station
# 1         34.018072      -118.288654                  Bus Stop
# 2         34.018241      -118.291541        Light Rail Station
# 3         34.091506      -118.124138       Rental Car Location
# 4         34.095091      -118.128615                     Hotel
# 5         34.095480      -118.126460                  Bus Stop
# 6         34.092469      -118.132307                  Bus Stop
# 7         34.187506      -118.133583  Bike Rental / Bike Share
# 8         34.189353      -118.136372              Intersection
# 9         34.139397      -118.036965                     Hotel
# 10        34.127690      -118.150102       Rental Car Location
# 11        34.127839      -118.148203              Intersection
# 12        33.872479      -118.080209                     Hotel
# 13        33.871673      -118.081303                     Hotel
# 14        33.871667      -118.081999                  Bus Stop
# 15        34.120225      -118.256538                     Hotel
# 16        33.343513      -118.325523                     Hotel
# 17        33.343052      -118.324963                     Hotel
# 18        33.343989      -118.327253                     Hotel
# 19        33.344593      -118.327165                     Hotel
# 20        33.342637      -118.328330                     Hotel
# 21        33.345011      -118.327119                     Hotel
# 22        33.343753      -118.327312                     Hotel
# 23        33.343406      -118.326634                     Hotel
# 24        33.344732      -118.327800                     Hotel
# 25        33.343733      -118.326164           Bed & Breakfast
# 26        33.343485      -118.325770                     Hotel
# 27        33.343700      -118.327266                     Hotel
# 28        33.343667      -118.327648                     Hotel
# 29        33.340970      -118.327645                     Hotel
# ..              ...              ...                       ...
# 567       34.046966      -118.446674              Intersection
# 568       34.046150      -118.449880               Bus Station
# 569       34.049317      -118.448474              Intersection
# 570       34.047361      -118.444253             Moving Target
# 571       34.047754      -118.444278                  Bus Stop
# 572       34.050882      -117.961450             Moving Target
# 573       34.053655      -117.962523             Boat or Ferry
# 574       34.107001      -117.806726               Bus Station
# 575       34.063275      -118.440950                     Hotel
# 576       34.063081      -118.442145                     Hotel
# 577       34.064465      -118.440886                  Bus Stop
# 578       34.069381      -118.439117               Bus Station
# 579       34.069440      -118.439102               Bus Station
# 580       34.063889      -118.439519               Bus Station
# 581       34.067074      -118.444609               Bus Station
# 582       34.063232      -118.441630                     Hotel
# 583       33.780102      -118.265099                     Hotel
# 584       33.780546      -118.258910       Rental Car Location
# 585       33.780300      -118.267900                     Hotel
# 586       34.076259      -118.319382             Moving Target
# 587       34.068864      -118.318573            Airport Lounge
# 588       34.068987      -118.323378                  Bus Stop
# 589       34.205285      -118.571380                     Motel
# 590       34.205084      -118.571363                     Motel
# 591       34.167618      -118.603206                     Hotel
# 592       34.169685      -118.605958              Intersection
# 593       34.168519      -118.605850              Intersection
# 594       34.168772      -118.605629                  Bus Stop
# 595       34.167908      -118.606049       Rental Car Location
# 596       34.168148      -118.601053                     Hotel
#
# [597 rows x 8 columns]
